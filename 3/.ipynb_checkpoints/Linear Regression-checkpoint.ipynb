# %% [markdown]
# ## Linear Regression
#
# Task: do a linear regression
#
# Our data $\bf d$ are described by a linear function $a{\bf x}+b$ plus some noise $\bf n$
#
# $$d_i = a x_i + b + n_i$$
#
# $d_i$ are the measured values for some measuring point $x_i$.
#
# The coefficiencts $a$ and $b$ are the same for all data $d_i$ and subsumed in a model vector
#
# $${\bf m}=\begin{bmatrix}a\\b\end{bmatrix} = \begin{bmatrix}m_1\\m_2\end{bmatrix}$$

# %% [markdown]
# The forward operator is linear with respect to m and can be written as ${\bf A}{\bf m}={\bf d}$ with
# $$
# {\bf A}=\begin{bmatrix}
# x_1 & 1\\
# x_2 & 1\\
# \ldots & \ldots \\
# x_D & 1
# \end{bmatrix}$$

# %% [markdown]
# **Task**: Write a function that creates a matrix for a set of given $x$ values. Create one for a given $x$ vector and plot some examples.

# %%
function LinRegMatrix(x)
    """Create Linear Regression matrix."""
    A = ones(length(x), 2)
    A[:, 1] = x[:]
    return A
end
# Out:
# LinRegMatrix (generic function with 1 method)

# %% [markdown]
# **Task**:
# 1. Create an x vector and a corresponding $\bf A$ matrix.
# 1. Compute data with Gaussian random noise (`randn` from `Statistics` module)
# 1. calculate a model and determine the residual
# 1. Plot the data along with the fitted curve
# 1. Plot mean value and standard deviation
# 1. Repeat with error weighting

# %%
using PyPlot
using Statistics
x = 0:0.1:3.0
error = 0.1
A = LinRegMatrix(x)
d = A * [0.5; -0.5] + randn(length(x)) .* error
# determine least-squares solution
m = A \ d[:]
print(m)
residual = A * m - d[:]
print("mean=", mean(residual), " std=", std(residual))
plot(x, d, "b+")
plot(x, A*m, "r-")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# [0.4877664158021923, -0.4816183024937284]mean=6.80459273157354e-17 std=0.10028120963816106
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000000E84308>

# %%
eresidual = residual / error
print("mean=", mean(eresidual), " std=", std(eresidual))
hist(eresidual, bins=20);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# mean=7.019474607307441e-16 std=1.0028120963816105

# %% [markdown]
# **Task**: compute the model and data resolution matrix

# %%
using LinearAlgebra
x
A = LinRegMatrix(x)
AT = transpose(A)
Ainv = inv(AT * A) * AT
RM = Ainv * A
display(RM)
RD = A * Ainv
matshow(RD)
clim([-0.1, 0.1])
set_cmap("bwr")
colorbar()
# Out:
# 2×2 Array{Float64,2}:
#  1.0          -5.55112e-17
#  5.55112e-17   1.0
# Figure(PyObject <Figure size 480x480 with 2 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x0000000001C71788>

# %%
plot(x, diag(RD))
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000001D03A88>

# %% [markdown]
# ### Lessons to be learned
# 1. The least-squares inversion minimizing the L2 norm is strongly connected to Gaussian statistics.
# 1. The error-weighted residual should (for large data numbers) show a Gaussian normal distribution (mean value of 0 and standard deviation of 1).
# 1. The misfit function should not show any systematics.
# 1. The model resolution of over-determined problems is identical (perfect resolution, uniquely defined solution)
# 1. The data resolution reflects the measurement

# %% [markdown]
# ## Tasks for exercise
# 1. Test with different values for the model and plot also the misfit ${\bf d}-{\bf Am}$
# 1. Increase the error level and look at the residual statistics.
# 1. Decrease and increase the number of measurements and watch statistics.
# 1. Test the same with common random noise instead of Gaussian noise.
# 1. Extend the matrix function to an arbitrary polynomial degree $P$
#
# $$ y_i = \sum\limits_{j=0}^P a_{ij} x^j $$
#
# (note the reversed order of coefficients)
#
# 1. Repeat the inversion by fitting a third-order polynomial.
# 1. Compute the singular value decomposition for different polynomial degrees.

# %%
using LinearAlgebra
rd = diag(RD)
plot(x, rd, "x-")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x00000000472F8588>

# %%
plot(x, RD[20, :], "x-")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000003C6BBB88>
